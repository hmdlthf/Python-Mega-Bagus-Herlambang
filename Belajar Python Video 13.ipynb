# %%
keranjangt = (1, 2, 3, 4, 5)

# %%
keranjangt2 = 1,2,3,4,5

# %%
keranjangt
# Out:
# (1, 2, 3, 4, 5)

# %%
keranjangt2
# Out:
# (1, 2, 3, 4, 5)

# %%
type(keranjangt)
# Out:
# tuple

# %%
t1 = (1,2,3,4,5,'a')

# %%
type(t1)
# Out:
# tuple

# %%
t2 = ("Python Masterclass Indonesia")

# %%
t2
# Out:
# 'Python Masterclass Indonesia'

# %%
t1 = ('Python Masterclass Indonesia')

# %%
L1 = [1,2,3,4,5]

# %%
L1
# Out:
# [1, 2, 3, 4, 5]

# %%
L1[1] = 'BARU'

# %%
L1
# Out:
# [1, 'BARU', 3, 4, 5]

# %%
keranjangt
# Out:
# (1, 2, 3, 4, 5)

# %%
keranjangt[2]
# Out:
# 3

# %%
keranjangt[-1]
# Out:
# 5

# %%
keranjangt
# Out:
# (1, 2, 3, 4, 5)

# %%
keranjangt = keranjangt[0], keranjangt[1], 'jeruk', keranjangt[3], keranjangt[4]

# %%
keranjangt
# Out:
# (1, 2, 'jeruk', 4, 5)

# %%
keranjangt = list(keranjangt)

# %%
keranjangt
# Out:
# [1, 2, 'jeruk', 4, 5]

# %%
keranjangt[3] = 'apel'

# %%
keranjangt
# Out:
# [1, 2, 'jeruk', 'apel', 5]

# %%
keranjangt
# Out:
# [1, 2, 'jeruk', 'apel', 5]

# %% [markdown]
# Methode di Tuples

# %%
t1 = (1,2,3,4,5,3,4,5,5,)

# %%
l1 = (1,2,3,4,5)

# %%
l1.count(5)
# Out:
# 1

# %%
t1.index(5)
# Out:
# 4

# %%
t1.index(4)
# Out:
# 3

# %% [markdown]
# Multiples Assigments And Tuples

# %%
a,b,c,d = 1,2,3,4

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %%
d
# Out:
# 4

# %%
a, b = 1,2

# %%
tas = ('rambutan', 41, 9.67, [2,3,4,5])

# %%
tas
# Out:
# ('rambutan', 41, 9.67, [2, 3, 4, 5])

# %%
item1, item2, item3, item4= tas

# %%
item1
# Out:
# 'rambutan'

# %%
item2
# Out:
# 41

# %%
item3
# Out:
# 9.67

# %%
item4
# Out:
# [2, 3, 4, 5]

# %% [markdown]
# sets
# sets adalah sebuah tipe data untuk elemen bersifat unik tanpa dupliasi dan tidak berurutan

# %%
set1 = set()

# %%
set1
# Out:
# set()

# %%
set1.add('biru')

# %%
set1
# Out:
# {'biru'}

# %%
set1.add('kuning')

# %%
set1
# Out:
# {'biru', 'kuning'}

# %%
list_angka = [1,2,3,4,5,6,7,8,9]

# %%
set_angka = set(list_angka)

# %%
set_angka
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %% [markdown]
# BOOLEAN, COMPARISON AND CONDITIONALS IN PYTHON

# %% [markdown]
# Boolean : sebuh tipe data yang memberikan nilai True dan False

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %% [markdown]
# Comparison Operators

# %% [markdown]
# == sama dengan
# != tidak sama dengan
# > lebih besar dari (eksklusif)
# < lebih kecil dari (eksklusif)
# >= Lebih besar dari (inklusif)
# <= lebih kecil dari (inklusif)

# %%
a = 35
print(a)
# Out:
# 35

# %%
'a' != 'a'
# Out:
# False

# %%
25 >= 25
# Out:
# True

# %% [markdown]
# comparison Operator Berantai

# %% [markdown]
# and = dua kondisi True untuk menghasilkan True
# or = salah satu kondisi True untuk menghasilkan True
# not = memberikan boolean yang berlawanan

# %%
3<5 and 6>5
# Out:
# True

# %%
not (3<4 or 4>6)
# Out:
# False

# %%
not True
# Out:
# False

# %%
not (2<3<10)
# Out:
# False

# %%
not (2<3 and 3<10)
# Out:
# False

# %% [markdown]
# CONDITIONAL

# %% [markdown]
# Ada 3 jenis sonditional yang bisa digunakan
# if
# elif
# else
#
# if(awbuha kondisi = True):
#     eksekusi
# else:
#     eksekusi
#
# if(sebuah kondisi = True):
#     eksekusi
# ilif(sebuah kondisi = True):
#     eksekusi
# else:
#     eksekusi

# %%
if 3>2:
    print('berhasil')
# Out:
# berhasil

# %%
if not False:
        print('berhasil')
# Out:
# berhasil

# %%
if not False:
    print ('berhasil')
else:
    print('berhasil')
# Out:
# berhasil

# %%
berat = 76

# %%
if (berat>100):
    print('kamu terlalu gemuk, diet ya')
elif 0<=berat<=50:
    print('kamu terlalu kurus, coba tambah makannya')
elif berat>50 and berat<79:
    print('kamu cukup idel')
else:
    print('beratmu pasti diantara 88-90 ya kan')
# Out:
# kamu cukup idel

# %% [markdown]
# FOR AND WHILE LOOPS

# %% [raw]
# For loops
# Digunakan untuk melakukan iterasi
# hampir semua objek di Pyhton bisa diiterasi
# aturan penulisan
#
# for item in penulisan
#     eksekusi perintah
