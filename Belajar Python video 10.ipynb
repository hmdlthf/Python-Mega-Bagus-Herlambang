# %% [markdown]
# Methode pyhton

# %%
var1 = 'makanan sehat itu 4 sehat 5 sempurna'

# %%
var1
# Out:
# 'makanan sehat itu 4 sehat 5 sempurna'

# %%
var1.upper()
# Out:
# 'MAKANAN SEHAT ITU 4 SEHAT 5 SEMPURNA'

# %%
var1.capitalize()
# Out:
# 'Makanan sehat itu 4 sehat 5 sempurna'

# %%
var1 = var1.upper()

# %%
var1.split()
# Out:
# ['MAKANAN', 'SEHAT', 'ITU', '4', 'SEHAT', '5', 'SEMPURNA']

# %% [markdown]
# NLP = NATURAL LANGUAGE PROCESSING

# %%
var1.split("A")
# Out:
# ['M', 'K', 'N', 'N SEH', 'T ITU 4 SEH', 'T 5 SEMPURN', '']

# %%
var1.split("S")
# Out:
# ['MAKANAN ', 'EHAT ITU 4 ', 'EHAT 5 ', 'EMPURNA']

# %%
var2 = [1, 2, 3, 4, 5]

# %%
type(var2)
# Out:
# list

# %%
var3 = "Official Manchester United Website"

# %%
var3.casefold()
# Out:
# 'official manchester united website'

# %%
var3.encode()
# Out:
# b'Official Manchester United Website'

# %%
var3.upper()
# Out:
# 'OFFICIAL MANCHESTER UNITED WEBSITE'

# %%
var3.split("e")
# Out:
# ['Official Manch', 'st', 'r Unit', 'd W', 'bsit', '']

# %%
var3.split("s")
# Out:
# ['Official Manche', 'ter United Web', 'ite']

# %%
var3.split()
# Out:
# ['Official', 'Manchester', 'United', 'Website']

# %% [markdown]
# PRINT METHODE DAN FORMATTING DI PYTHON

# %%
var1 = "ayam goreng KFC dan MCD mana yang lebih enak"

# %%
print(var1)
# Out:
# ayam goreng KFC dan MCD mana yang lebih enak

# %%
 print("ini ada {} buah".format('10'))
# Out:
# ini ada 10 buah

# %%
print("Kekalahan Man u musim ini {} pertandingan".format(4))
# Out:
# Kekalahan Man u musim ini 4 pertandingan

# %%
print ('klasemen liga inggris pekan 23 adalah (2) (0) (1)'.format('ManU','ManC','Leicester'))
# Out:
# klasemen liga inggris pekan 23 adalah (2) (0) (1)

# %%
print ('klasemen liga inggris pekan 23 adalah (a) (c) (b)'.format(c='ManU', b='ManC', a='Leicester'))
# Out:
# klasemen liga inggris pekan 23 adalah (a) (c) (b)

# %%
phi = 22/7

# %%
phi
# Out:
# 3.142857142857143

# %%
print('untuk menghitung luas lingkarangan, gunakanlah phi = {}'.format(phi))
# Out:
# untuk menghitung luas lingkarangan, gunakanlah phi = 3.142857142857143

# %%
luas1 = 776.9

# %%
luas2 = 885.9

# %% [markdown]
# FORMAT PENULISAN UNTUK METHODE PRINT (NILAI:LEBAR:TINGKAT_PESISI F)

# %%
print('luas tanah yang dimiliki oleh pak budi adalah')
